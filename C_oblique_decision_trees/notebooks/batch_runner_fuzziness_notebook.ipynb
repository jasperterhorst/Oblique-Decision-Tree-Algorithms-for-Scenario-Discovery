# %%
import os
import pandas as pd

from C_oblique_decision_trees.visualization import (
    plot_metric_vs_depth_per_dataset_and_algorithm,
    plot_metric_vs_depth_per_algorithm,
    plot_metric_vs_depth_per_shape,
    plot_seed_std_vs_depth_per_algorithm,
    plot_benchmark_metrics,
    plot_coverage_density_all_shapes_for_algorithm, 
    plot_runtime_per_shape_grouped_by_noise_and_algorithm)

from src.config.paths import DEPTH_SWEEP_BATCH_RESULTS_OUTPUTS_DIR

# %%
# Load CSV
results_file = os.path.join(DEPTH_SWEEP_BATCH_RESULTS_OUTPUTS_DIR, "all_algorithms_all_datasets.csv")
df = pd.read_csv(results_file)

# %% [markdown]
# Metrics to be chosen from: accuracy, coverage, density, f_score, gini_coverage_all_leaves, gini_density_all_leaves, and runtime.

# %% [markdown]
# ## Algorithms on both 2D and 3D datasets

# %%
plot_benchmark_metrics(df, metric="coverage", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True)
plot_benchmark_metrics(df, metric="density", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True)
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\coverage_vs_depth_by_algorithm_shape_type.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\density_vs_depth_by_algorithm_shape_type.pdf
# <Axes: title={'center': 'Density vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Density'>

# %% [markdown]
# ### Checking runtime

# %%
plot_benchmark_metrics(df, metric="runtime", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["HHCART A"]})
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\runtime_vs_depth_by_algorithm_shape_type.pdf
# <Axes: title={'center': 'Runtime vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Runtime'>

# %% [markdown]
# ## Dropping WODT, CART and CO2

# %%
plot_benchmark_metrics(df, metric="coverage", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "CART"]})
plot_benchmark_metrics(df, metric="density", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "CART"]})
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\coverage_vs_depth_by_algorithm_shape_type.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\density_vs_depth_by_algorithm_shape_type.pdf
# <Axes: title={'center': 'Density vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Density'>

# %% [markdown]
# ## Dropping Rand Cart and Ridge Cart

# %%
plot_benchmark_metrics(df, metric="coverage", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART"]})
plot_benchmark_metrics(df, metric="density", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART"]})
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\coverage_vs_depth_by_algorithm_shape_type.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\density_vs_depth_by_algorithm_shape_type.pdf
# <Axes: title={'center': 'Density vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Density'>

# %%
plot_benchmark_metrics(df, metric="runtime", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART"]})
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\runtime_vs_depth_by_algorithm_shape_type.pdf
# <Axes: title={'center': 'Runtime vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Runtime'>

# %% [markdown]
# ## Dropping HHCART A

# %%
plot_benchmark_metrics(df, metric="coverage", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART", "HHCART A"]})
plot_benchmark_metrics(df, metric="density", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART", "HHCART A"]})
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\coverage_vs_depth_by_algorithm_shape_type.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\density_vs_depth_by_algorithm_shape_type.pdf
# <Axes: title={'center': 'Density vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Density'>

# %%
plot_benchmark_metrics(df, metric="gini_coverage_all_leaves", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART", "HHCART A"]})
plot_benchmark_metrics(df, metric="gini_density_all_leaves", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART", "HHCART A"]})
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\gini_coverage_all_leaves_vs_depth_by_algorithm_shape_type.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\gini_density_all_leaves_vs_depth_by_algorithm_shape_type.pdf
# <Axes: title={'center': 'Gini Density vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Gini Density'>

# %%
plot_benchmark_metrics(df, metric="gini_coverage_all_leaves", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "HHCART A"]})
plot_benchmark_metrics(df, metric="gini_density_all_leaves", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "HHCART A"]})
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\gini_coverage_all_leaves_vs_depth_by_algorithm_shape_type.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\gini_density_all_leaves_vs_depth_by_algorithm_shape_type.pdf
# <Axes: title={'center': 'Gini Density vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Gini Density'>

# %%
plot_benchmark_metrics(df, metric="runtime", group_by=["algorithm", "dataset"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=True, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART", "HHCART A"]})
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\runtime_vs_depth_by_algorithm_shape_type.pdf
# <Axes: title={'center': 'Runtime vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Runtime'>

# %% [markdown]
# ## Showing HHCART is deterministic for when we add extra dimensionality.

# %%
plot_benchmark_metrics(df, metric="coverage", group_by=["dataset", "algorithm"], show_std=True, filter_noise=True, max_depth=8, group_by_shape_type=False, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART", "HHCART A", "HHCART D"]})
plot_benchmark_metrics(df, metric="density", group_by=["dataset", "algorithm"], show_std=True, filter_noise=True, max_depth=8, group_by_shape_type=False, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART", "HHCART A", "HHCART D"]})
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\coverage_vs_depth_by_dataset_algorithm.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\density_vs_depth_by_dataset_algorithm.pdf
# <Axes: title={'center': 'Density vs Depth by Dataset and Algorithm'}, xlabel='Depth', ylabel='Density'>

# %%
plot_benchmark_metrics(df, metric="coverage", group_by=["dataset", "algorithm"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=False, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART", "HHCART A", "OC1"]})
plot_benchmark_metrics(df, metric="density", group_by=["dataset", "algorithm"], show_std=False, filter_noise=True, max_depth=8, group_by_shape_type=False, exclude={"algorithm": ["WODT", "CO2", "CART", "RANDCART", "RIDGE CART", "HHCART A", "OC1"]})
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\coverage_vs_depth_by_dataset_algorithm.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\density_vs_depth_by_dataset_algorithm.pdf
# <Axes: title={'center': 'Density vs Depth by Dataset and Algorithm'}, xlabel='Depth', ylabel='Density'>
