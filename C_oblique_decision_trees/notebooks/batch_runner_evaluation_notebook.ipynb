# %%
import os
import pandas as pd

from C_oblique_decision_trees.visualization import plot_benchmark_metrics, plot_coverage_density_all_shapes_for_algorithm, plot_runtime_over_depth, plot_scaling_loglog, plot_metrics_vs_depth_grouped_by_dims_or_samples, plot_metrics_vs_depth_grouped_by_label_noise

from src.config.paths import DEPTH_SWEEP_BATCH_RESULTS_OUTPUTS_DIR

# %%
# Load CSV
results_file = os.path.join(DEPTH_SWEEP_BATCH_RESULTS_OUTPUTS_DIR, "concatenated_delftblue_label_noise_runs.csv")
df = pd.read_csv(results_file)

# %% [markdown]
# Metrics to be chosen from: accuracy, coverage, density, f_score, gini_coverage_all_leaves, gini_density_all_leaves, and runtime.

# %% [markdown]
# ## Algorithms on both 2D and 3D datasets

# %%
plot_benchmark_metrics(df, metric="runtime", group_by=["algorithm"], show_std=False, filter_noise=True, max_depth=8, title_postfix="_all_algorithms_dimensions_combined")
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\runtime\runtime_vs_depth_by_algorithm_all_algorithms_dimensions_combined.pdf
# <Axes: title={'center': 'Runtime vs Depth by Algorithm'}, xlabel='Depth', ylabel='Runtime'>

# %%
plot_benchmark_metrics(df, metric="runtime", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, title_postfix="_all_algorithms_dimensions_separated")
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\runtime\runtime_vs_depth_by_algorithm_shape_type_all_algorithms_dimensions_separated.pdf
# <Axes: title={'center': 'Runtime vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Runtime'>

# %%
plot_benchmark_metrics(df, metric="accuracy", group_by=["algorithm"], show_std=False, filter_noise=True, max_depth=8, title_postfix="_all_algorithms_dimensions_combined")
plot_benchmark_metrics(df, metric="coverage", group_by=["algorithm"], show_std=False, filter_noise=True, max_depth=8, title_postfix="_all_algorithms_dimensions_combined")
plot_benchmark_metrics(df, metric="density", group_by=["algorithm"], show_std=False, filter_noise=True, max_depth=8, title_postfix="_all_algorithms_dimensions_combined")
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\accuracy\accuracy_vs_depth_by_algorithm_all_algorithms_dimensions_combined.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\coverage\coverage_vs_depth_by_algorithm_all_algorithms_dimensions_combined.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\density\density_vs_depth_by_algorithm_all_algorithms_dimensions_combined.pdf
# <Axes: title={'center': 'Density vs Depth by Algorithm'}, xlabel='Depth', ylabel='Density'>

# %%
plot_benchmark_metrics(df, metric="accuracy", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, title_postfix="_all_algorithms_dimensions_separated")
plot_benchmark_metrics(df, metric="coverage", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, title_postfix="_all_algorithms_dimensions_separated")
plot_benchmark_metrics(df, metric="density", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, title_postfix="_all_algorithms_dimensions_separated")
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\accuracy\accuracy_vs_depth_by_algorithm_shape_type_all_algorithms_dimensions_separated.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\coverage\coverage_vs_depth_by_algorithm_shape_type_all_algorithms_dimensions_separated.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\density\density_vs_depth_by_algorithm_shape_type_all_algorithms_dimensions_separated.pdf
# <Axes: title={'center': 'Density vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Density'>

# %% [markdown]
# ### Checking runtime

# %%
plot_benchmark_metrics(df, metric="runtime", group_by=["algorithm"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a"]}, title_postfix="_hhcart_a_dropped_dimensions_combined")
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\runtime\runtime_vs_depth_by_algorithm_hhcart_a_dropped_dimensions_combined.pdf
# <Axes: title={'center': 'Runtime vs Depth by Algorithm'}, xlabel='Depth', ylabel='Runtime'>

# %%
plot_benchmark_metrics(df, metric="runtime", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a"]}, title_postfix="_hhcart_a_dropped_dimensions_separated")
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\runtime\runtime_vs_depth_by_algorithm_shape_type_hhcart_a_dropped_dimensions_separated.pdf
# <Axes: title={'center': 'Runtime vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Runtime'>

# %% [markdown]
# ## Dropping WODT and CART

# %%
plot_benchmark_metrics(df, metric="accuracy", group_by=["algorithm"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a", "wodt", "cart"]}, title_postfix="_hhcart_a_wodt_cart_co2_dropped_dimensions_combined")
plot_benchmark_metrics(df, metric="coverage", group_by=["algorithm"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a", "wodt", "cart"]}, title_postfix="_hhcart_a_wodt_cart_co2_dropped_dimensions_combined")
plot_benchmark_metrics(df, metric="density", group_by=["algorithm"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a", "wodt", "cart"]}, title_postfix="_hhcart_a_wodt_cart_co2_dropped_dimensions_combined")
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\accuracy\accuracy_vs_depth_by_algorithm_hhcart_a_wodt_cart_co2_dropped_dimensions_combined.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\coverage\coverage_vs_depth_by_algorithm_hhcart_a_wodt_cart_co2_dropped_dimensions_combined.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\density\density_vs_depth_by_algorithm_hhcart_a_wodt_cart_co2_dropped_dimensions_combined.pdf
# <Axes: title={'center': 'Density vs Depth by Algorithm'}, xlabel='Depth', ylabel='Density'>

# %%
plot_benchmark_metrics(df, metric="accuracy", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["wodt", "cart"]}, title_postfix="_hhcart_a_wodt_cart_co2_dropped_dimensions_separated")
plot_benchmark_metrics(df, metric="coverage", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["wodt", "cart"]}, title_postfix="_hhcart_a_wodt_cart_co2_dropped_dimensions_separated")
plot_benchmark_metrics(df, metric="density", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["wodt", "cart"]}, title_postfix="_hhcart_a_wodt_cart_co2_dropped_dimensions_separated")
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\accuracy\accuracy_vs_depth_by_algorithm_shape_type_hhcart_a_wodt_cart_co2_dropped_dimensions_separated.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\coverage\coverage_vs_depth_by_algorithm_shape_type_hhcart_a_wodt_cart_co2_dropped_dimensions_separated.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\density\density_vs_depth_by_algorithm_shape_type_hhcart_a_wodt_cart_co2_dropped_dimensions_separated.pdf
# <Axes: title={'center': 'Density vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Density'>

# %% [markdown]
# ## Dropping Rand Cart and Ridge Cart

# %%
plot_benchmark_metrics(df, metric="accuracy", group_by=["algorithm"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a", "wodt", "cart", "randcart", "ridge_cart"]}, title_postfix="_hhcart_d_oc1_left_dimensions_combined")
plot_benchmark_metrics(df, metric="coverage", group_by=["algorithm"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a", "wodt", "cart", "randcart", "ridge_cart"]}, title_postfix="_hhcart_d_oc1_left_dimensions_combined")
plot_benchmark_metrics(df, metric="density", group_by=["algorithm"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a", "wodt", "cart", "randcart", "ridge_cart"]}, title_postfix="_hhcart_d_oc1_left_dimensions_combined")
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\accuracy\accuracy_vs_depth_by_algorithm_hhcart_d_oc1_left_dimensions_combined.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\coverage\coverage_vs_depth_by_algorithm_hhcart_d_oc1_left_dimensions_combined.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\density\density_vs_depth_by_algorithm_hhcart_d_oc1_left_dimensions_combined.pdf
# <Axes: title={'center': 'Density vs Depth by Algorithm'}, xlabel='Depth', ylabel='Density'>

# %%
plot_benchmark_metrics(df, metric="accuracy", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a", "wodt", "cart", "randcart", "ridge_cart"]}, title_postfix="_hhcart_d_oc1_left_dimensions_separated")
plot_benchmark_metrics(df, metric="coverage", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a", "wodt", "cart", "randcart", "ridge_cart"]}, title_postfix="_hhcart_d_oc1_left_dimensions_separated")
plot_benchmark_metrics(df, metric="density", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a", "wodt", "cart", "randcart", "ridge_cart"]}, title_postfix="_hhcart_d_oc1_left_dimensions_separated")
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\accuracy\accuracy_vs_depth_by_algorithm_shape_type_hhcart_d_oc1_left_dimensions_separated.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\coverage\coverage_vs_depth_by_algorithm_shape_type_hhcart_d_oc1_left_dimensions_separated.pdf
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\density\density_vs_depth_by_algorithm_shape_type_hhcart_d_oc1_left_dimensions_separated.pdf
# <Axes: title={'center': 'Density vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Density'>

# %%
plot_benchmark_metrics(df, metric="runtime", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["hhcart_a", "wodt", "cart", "randcart", "ridge_cart"]})
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\runtime\runtime_vs_depth_by_algorithm_shape_type.pdf
# <Axes: title={'center': 'Runtime vs Depth by Algorithm and Shape type'}, xlabel='Depth', ylabel='Runtime'>

# %% [markdown]
# ## Other metrics

# %%
# plot_benchmark_metrics(df, metric="gini_coverage_all_leaves", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["wodt", "cart", "randcart", "ridge_cart", "hhcart_a"]})
# plot_benchmark_metrics(df, metric="gini_density_all_leaves", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["wodt", "cart", "randcart", "ridge_cart", "hhcart_a"]})

# %%
# plot_benchmark_metrics(df, metric="gini_coverage_all_leaves", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["wodt", "hhcart_a"]})
# plot_benchmark_metrics(df, metric="gini_density_all_leaves", group_by=["algorithm", "shape_type"], show_std=False, filter_noise=True, max_depth=8, exclude={"algorithm": ["wodt", "hhcart_a"]})

# %% [markdown]
# # Analysing OC1 and HHCART D Runtimes for Different Number of Dimensions

# %%
# Load CSV
results_file_dimensionality = os.path.join(DEPTH_SWEEP_BATCH_RESULTS_OUTPUTS_DIR, "concatenated_delftblue_dimensionality_runs.csv")
df_dimensionality = pd.read_csv(results_file_dimensionality)

# %%
plot_runtime_over_depth(df_dimensionality, algorithm="OC1", vary_by="data_dim", title="Effect of Feature Count on OC1 Runtime", save_name="dimensionality_runtime_plot_oc1.pdf", y_bounds=(0,2500))
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_data_dim\dimensionality_runtime_plot_oc1.pdf
# <Axes: title={'center': 'Effect of Feature Count on OC1 Runtime'}, xlabel='Depth', ylabel='Runtime (s)'>

# %%
plot_runtime_over_depth(df_dimensionality, algorithm="hhcart d", vary_by="data_dim", title="Effect of Feature Count on HHCART D Runtime", save_name="dimensionality_runtime_plot_hhcart_d.pdf", y_bounds=(0,2500))
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_data_dim\dimensionality_runtime_plot_hhcart_d.pdf
# <Axes: title={'center': 'Effect of Feature Count on HHCART D Runtime'}, xlabel='Depth', ylabel='Runtime (s)'>

# %% [markdown]
# # Analysing OC1 and HHCART D Runtimes for Different Dataset Sizes

# %%
# Load CSV
results_file_sample_size = os.path.join(DEPTH_SWEEP_BATCH_RESULTS_OUTPUTS_DIR, "concatenated_delftblue_sample_size_runs.csv")
df_sample_size = pd.read_csv(results_file_sample_size)

# %%
plot_runtime_over_depth(df_sample_size, algorithm="OC1", vary_by="n_samples", title="Effect of Sample Size on OC1 Runtime", save_name="sample_size_runtime_plot_oc1.pdf", y_bounds=(0,250))
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_n_samples\sample_size_runtime_plot_oc1.pdf
# <Axes: title={'center': 'Effect of Sample Size on OC1 Runtime'}, xlabel='Depth', ylabel='Runtime (s)'>

# %%
plot_runtime_over_depth(df_sample_size, algorithm="hhcart d", vary_by="n_samples", title="Effect of Sample Size on HHCART D Runtime", save_name="sample_size_runtime_plot_hhcart_d.pdf", y_bounds=(0,250))
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_n_samples\sample_size_runtime_plot_hhcart_d.pdf
# <Axes: title={'center': 'Effect of Sample Size on HHCART D Runtime'}, xlabel='Depth', ylabel='Runtime (s)'>

# %% [markdown]
# # LogLog Version

# %%
plot_scaling_loglog(df_dimensionality, vary_by="data_dim", algorithms=("OC1", "HHCART D"), title="Runtime Scaling with Feature Count", save_name="logged_runtime_vs_feature_count_combined.pdf", fixed_depth=6)
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_data_dim\logged_runtime_vs_feature_count_combined.pdf
# <Axes: title={'center': 'Runtime Scaling with Feature Count'}, xlabel='Feature Count', ylabel='Runtime (s)'>

# %%
plot_scaling_loglog(df_sample_size, vary_by="n_samples", algorithms=("OC1", "HHCART D"), title="Runtime Scaling with Sample Size",
                    save_name="logged_runtime_vs_sample_size_combined.pdf", fixed_depth=6)
# Out:
# Figure saved: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_data_dim\logged_runtime_vs_sample_size_combined.pdf
# <Axes: title={'center': 'Runtime Scaling with Sample Size'}, xlabel='Sample Count', ylabel='Runtime (s)'>

# %%
plot_metrics_vs_depth_grouped_by_dims_or_samples(
    df=df_dimensionality,
    algorithm="OC1",
    input_axis="data_dim",
    metrics=("accuracy", "coverage", "density")
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\depth_trajectories\oc1_metric_trajectories_by_data_dim.pdf

# %%
plot_metrics_vs_depth_grouped_by_dims_or_samples(
    df=df_dimensionality,
    algorithm="hhcart_d",
    input_axis="data_dim",
    metrics=("accuracy", "coverage", "density")
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\depth_trajectories\hhcart_d_metric_trajectories_by_data_dim.pdf

# %%
plot_metrics_vs_depth_grouped_by_dims_or_samples(
    df=df_sample_size,
    algorithm="OC1",
    input_axis="n_samples",
    metrics=("accuracy", "coverage", "density")
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\depth_trajectories\oc1_metric_trajectories_by_n_samples.pdf

# %%
plot_metrics_vs_depth_grouped_by_dims_or_samples(
    df=df_sample_size,
    algorithm="hhcart_d",
    input_axis="n_samples",
    metrics=("accuracy", "coverage", "density")
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\depth_trajectories\hhcart_d_metric_trajectories_by_n_samples.pdf

# %%
plot_metrics_vs_depth_grouped_by_label_noise(
    df=df,
    algorithm="OC1",
    metrics=("accuracy", "coverage", "density"),
    save_name="oc1_performance_by_label_noise.pdf"
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\performance_by_label_noise\oc1_performance_by_label_noise.pdf

# %%
plot_metrics_vs_depth_grouped_by_label_noise(
    df=df,
    algorithm="HHCART D",
    metrics=("accuracy", "coverage", "density"),
    save_name="hhcart_d_performance_by_label_noise.pdf"
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\performance_by_label_noise\hhcart_d_performance_by_label_noise.pdf
