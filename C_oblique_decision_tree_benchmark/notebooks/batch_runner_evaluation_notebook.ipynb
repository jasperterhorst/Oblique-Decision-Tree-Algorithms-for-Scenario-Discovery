# %%
import os
import pandas as pd

from C_oblique_decision_tree_benchmark.visualization import plot_metric_over_depth_by_algorithm_and_group, plot_coverage_density_all_shapes_for_algorithm, plot_runtime_over_depth_grouped_by_data_dim_or_samples, plot_loglog_runtime_scaling_by_dimension_or_sample_count, plot_multiple_metrics_over_depth_by_dim_or_sample_size, plot_multiple_metrics_over_depth_by_label_noise

from src.config.paths import DEPTH_SWEEP_BATCH_RESULTS_OUTPUTS_DIR

# %%
# Load CSV
results_file = os.path.join(DEPTH_SWEEP_BATCH_RESULTS_OUTPUTS_DIR, "concatenated_delftblue_label_noise_runs.csv")
df = pd.read_csv(results_file)

# %% [markdown]
# ## Algorithms on both 2D and 3D datasets

# %%
plot_metric_over_depth_by_algorithm_and_group(df, metric=["runtime"], 
                                              group_by=["algorithm"], 
                                              show_std=False, 
                                              filter_noise=True, 
                                              max_depth=8, 
                                              exclude={"algorithm": []}, 
                                              title="Runtime vs Depth for All Algorithms",
                                              title_postfix="_all_algorithms_dimensions_combined")
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\runtime_vs_depth_by_algorithm_all_algorithms_dimensions_combined.pdf

# %%
# plot_metric_over_depth_by_algorithm_and_group(df, metric=["coverage", "density", "accuracy"], 
#                                               group_by=["algorithm"], 
#                                               show_std=False, 
#                                               filter_noise=True, 
#                                               max_depth=8, 
#                                               exclude={"algorithm": ["cart", "hhcart_a"]}, 
#                                               title="Coverage, Density, and Accuracy vs Depth by Algorithm",
#                                               title_postfix="_hhcart_a_dropped_dimensions_combined")

# %%
plot_metric_over_depth_by_algorithm_and_group(df, metric=["coverage", "density", "accuracy"],
                                              group_by=["algorithm", "shape_type"],
                                              show_std=False,
                                              filter_noise=True,
                                              max_depth=8,
                                              exclude={"algorithm": ["hhcart_a"]},
                                              title="Coverage, Density, and Accuracy vs Depth by Algorithm and Shape Type",
                                              title_postfix="_hhcart_a_dropped_dimensions_separated")
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\coverage_density_accuracy_vs_depth_by_algorithm_shape_type_hhcart_a_dropped_dimensions_separated.pdf

# %%
# plot_metric_over_depth_by_algorithm_and_group(df, metric=["coverage", "density"], 
#                                               group_by=["algorithm"], 
#                                               show_std=False, 
#                                               filter_noise=True, 
#                                               max_depth=8, 
#                                               exclude={"algorithm": ["cart", "hhcart_a"]}, 
#                                               title="Coverage and Density vs Depth by Algorithm",
#                                               title_postfix="_hhcart_a_dropped_dimensions_combined")

# %%
plot_metric_over_depth_by_algorithm_and_group(df, metric=["coverage", "density"], 
                                              group_by=["algorithm", "shape_type"], 
                                              show_std=False, 
                                              filter_noise=True, 
                                              max_depth=8, 
                                              exclude={"algorithm": ["cart", "hhcart_a"]}, 
                                              title="Coverage and Accuracy vs Depth by Algorithm and Shape Type",
                                              title_postfix="_hhcart_a_dropped_dimensions_separated")
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\coverage_density_vs_depth_by_algorithm_shape_type_hhcart_a_dropped_dimensions_separated.pdf

# %% [markdown]
# # Dropping WODT, RANDCART and Ridge CART

# %%
# plot_metric_over_depth_by_algorithm_and_group(df, metric=["coverage", "density"],
#                                               group_by=["algorithm"],
#                                               show_std=False,
#                                               filter_noise=True,
#                                               max_depth=8,
#                                               exclude={"algorithm": ["hhcart_a", "wodt", "cart", "randcart", "ridge_cart"]},
#                                               title="Coverage and Density vs Depth by Algorithm",
#                                               title_postfix="_all_dropped_combined")

# %%
plot_metric_over_depth_by_algorithm_and_group(df, metric=["coverage", "density"],
                                              group_by=["algorithm", "shape_type"],
                                              show_std=False,
                                              filter_noise=True,
                                              max_depth=8,
                                              exclude={"algorithm": ["hhcart_a", "wodt", "cart", "randcart", "ridge_cart"]},
                                              title="Coverage and Density vs Depth by Algorithm",
                                              title_postfix="_all_dropped_separated")
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\coverage_density_vs_depth_by_algorithm_shape_type_all_dropped_separated.pdf

# %%
plot_metric_over_depth_by_algorithm_and_group(df, metric=["runtime"],
                                              group_by=["algorithm", "shape_type"],
                                              show_std=False,
                                              filter_noise=True,
                                              max_depth=8,
                                              exclude={"algorithm": ["hhcart_a", "wodt", "cart", "randcart", "ridge_cart"]},
                                              title="Runtime vs Depth OC1 and HHCART D",
                                              title_postfix="_all_dropped_separated")
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\plot_over_depth\runtime_vs_depth_by_algorithm_shape_type_all_dropped_separated.pdf

# %% [markdown]
# # Analysing OC1 and HHCART D Runtimes for Different Number of Dimensions

# %%
# Load CSV
results_file_dimensionality = os.path.join(DEPTH_SWEEP_BATCH_RESULTS_OUTPUTS_DIR, "concatenated_delftblue_dimensionality_runs.csv")
df_dimensionality = pd.read_csv(results_file_dimensionality)

# %%
plot_runtime_over_depth_grouped_by_data_dim_or_samples(df_dimensionality, algorithm="OC1", vary_by="data_dim", title="Effect of Feature Count \n on OC1 Runtime", save_name="dimensionality_runtime_plot_oc1.pdf", y_bounds=(0,2500))
# Out:
# [FIGURE SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_data_dim\dimensionality_runtime_plot_oc1.pdf
# <Axes: title={'center': 'Effect of Feature Count \n on OC1 Runtime'}, xlabel='Depth', ylabel='Runtime (s)'>

# %%
plot_runtime_over_depth_grouped_by_data_dim_or_samples(df_dimensionality, algorithm="hhcart d", vary_by="data_dim", title="Effect of Feature Count \n on HHCART D Runtime", save_name="dimensionality_runtime_plot_hhcart_d.pdf", y_bounds=(0,2500))
# Out:
# [FIGURE SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_data_dim\dimensionality_runtime_plot_hhcart_d.pdf
# <Axes: title={'center': 'Effect of Feature Count \n on HHCART D Runtime'}, xlabel='Depth', ylabel='Runtime (s)'>

# %% [markdown]
# # Analysing OC1 and HHCART D Runtimes for Different Dataset Sizes

# %%
# Load CSV
results_file_sample_size = os.path.join(DEPTH_SWEEP_BATCH_RESULTS_OUTPUTS_DIR, "concatenated_delftblue_sample_size_runs.csv")
df_sample_size = pd.read_csv(results_file_sample_size)

# %%
plot_runtime_over_depth_grouped_by_data_dim_or_samples(df_sample_size, algorithm="OC1", vary_by="n_samples", title="Effect of Sample Size \n on OC1 Runtime", save_name="sample_size_runtime_plot_oc1.pdf", y_bounds=(0,250))
# Out:
# [FIGURE SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_n_samples\sample_size_runtime_plot_oc1.pdf
# <Axes: title={'center': 'Effect of Sample Size \n on OC1 Runtime'}, xlabel='Depth', ylabel='Runtime (s)'>

# %%
plot_runtime_over_depth_grouped_by_data_dim_or_samples(df_sample_size, algorithm="hhcart d", vary_by="n_samples", title="Effect of Sample Size \n on HHCART D Runtime", save_name="sample_size_runtime_plot_hhcart_d.pdf", y_bounds=(0,250))
# Out:
# [FIGURE SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_n_samples\sample_size_runtime_plot_hhcart_d.pdf
# <Axes: title={'center': 'Effect of Sample Size \n on HHCART D Runtime'}, xlabel='Depth', ylabel='Runtime (s)'>

# %% [markdown]
# # LogLog Version

# %%
plot_loglog_runtime_scaling_by_dimension_or_sample_count(df_dimensionality, vary_by="data_dim", algorithms=("OC1", "HHCART D"), title="Runtime Scaling with Feature Count", save_name="logged_runtime_vs_feature_count_combined.pdf", fixed_depth=1)
# Out:
# [FIGURE SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_data_dim\logged_runtime_vs_feature_count_combined.pdf
# <Axes: title={'center': 'Runtime Scaling with Feature Count'}, xlabel='Feature Count', ylabel='Runtime (s)'>

# %%
plot_loglog_runtime_scaling_by_dimension_or_sample_count(df_dimensionality, vary_by="data_dim", algorithms=("OC1", "HHCART D"), title="Runtime Scaling with Feature Count", save_name="logged_runtime_vs_feature_count_combined.pdf", fixed_depth=6)
# Out:
# [FIGURE SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_data_dim\logged_runtime_vs_feature_count_combined.pdf
# <Axes: title={'center': 'Runtime Scaling with Feature Count'}, xlabel='Feature Count', ylabel='Runtime (s)'>

# %%
plot_loglog_runtime_scaling_by_dimension_or_sample_count(df_sample_size, vary_by="n_samples", algorithms=("OC1", "HHCART D"), title="Runtime Scaling with Sample Size", save_name="logged_runtime_vs_sample_size_combined.pdf", fixed_depth=6)
# Out:
# [FIGURE SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\runtime_by_data_dim\logged_runtime_vs_sample_size_combined.pdf
# <Axes: title={'center': 'Runtime Scaling with Sample Size'}, xlabel='Sample Size', ylabel='Runtime (s)'>

# %%
plot_multiple_metrics_over_depth_by_dim_or_sample_size(
    df=df_dimensionality,
    algorithm="OC1",
    input_axis="data_dim",
    max_depth=8,
    metrics=("accuracy", "coverage", "density")
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\depth_trajectories\oc1_metric_trajectories_by_data_dim.pdf

# %%
plot_multiple_metrics_over_depth_by_dim_or_sample_size(
    df=df_dimensionality,
    algorithm="hhcart_d",
    input_axis="data_dim",
    max_depth=8,
    metrics=("accuracy", "coverage", "density")
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\depth_trajectories\hhcart_d_metric_trajectories_by_data_dim.pdf

# %%
plot_multiple_metrics_over_depth_by_dim_or_sample_size(
    df=df_sample_size,
    algorithm="OC1",
    input_axis="n_samples",
    max_depth=8,
    metrics=("accuracy", "coverage", "density")
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\depth_trajectories\oc1_metric_trajectories_by_n_samples.pdf

# %%
plot_multiple_metrics_over_depth_by_dim_or_sample_size(
    df=df_sample_size,
    algorithm="hhcart_d",
    input_axis="n_samples",
    max_depth=8,
    metrics=("accuracy", "coverage", "density")
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\depth_trajectories\hhcart_d_metric_trajectories_by_n_samples.pdf

# %%
plot_multiple_metrics_over_depth_by_label_noise(
    df=df,
    algorithm="OC1",
    metrics=("accuracy", "coverage", "density"),
    max_depth=8,
    save_name="oc1_performance_by_label_noise.pdf",
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\performance_by_label_noise\oc1_performance_by_label_noise.pdf

# %%
plot_multiple_metrics_over_depth_by_label_noise(
    df=df,
    algorithm="HHCART D",
    metrics=("accuracy", "coverage", "density"),
    max_depth=8,
    save_name="hhcart_d_performance_by_label_noise.pdf",
)
# Out:
# [SAVED] C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\_data\depth_sweep_batch_results\plots\performance_by_label_noise\hhcart_d_performance_by_label_noise.pdf
