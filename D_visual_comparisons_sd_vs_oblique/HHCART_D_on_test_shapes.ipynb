# %%
from HHCART_SD import HHCartD, load_model
from src.load_shapes import load_shape_dataset

# %%
# # Load and unpack a specific dataset
# dataset_name = "barbell_2d_label_noise_000"
# X, y = load_shape_dataset(folder_name="shapes")[dataset_name]

# %%
# # Load and unpack a specific dataset
# dataset_name = "radial_segment_2d_label_noise_000"
# X, y = load_shape_dataset(folder_name="shapes")[dataset_name]
# 
# # Set tree parameters
# max_depth = 8
# min_purity = 1.00
# 
# # Instantiate HHCART, build and save tree
# hh = HHCartD(X, y, min_purity=min_purity, max_depth=max_depth)
# hh.build_tree(f"{dataset_name}_max_depth_{max_depth}_min_purity_{str(min_purity).replace('.', '_')}")

# %%
hh = load_model("radial_segment_2d_label_noise_000_max_depth_8_min_purity_1_0")
# Out:
# [✅] Model successfully loaded from: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\D_visual_comparisons_sd_vs_oblique\data\radial_segment_2d_label_noise_000_max_depth_8_min_purity_1_0\model

# %%
hh.select(depth=3)
hh.inspect()
# Out:
# [✓] Selected tree at depth 3.
#
# [🔍] Inspecting tree at selected depth 3...
#
# [Node id=0, depth=0, impurity=0.3917] (split: -0.00*x0 +1.00*x1 + -0.20 >= 0)
# ├── [Node id=1, depth=1, impurity=0.0573] (split: -0.01*x0 +1.00*x1 + -0.17 >= 0)
# ├── ├── [Node id=2, depth=2, impurity=0.0098] (split: +1.00*x1 + -0.16 >= 0)
# ├── ├── ├── [Node id=3, depth=3] (leaf: prediction=0, purity=1.00, samples=1605)
# ├── ├── └── [Node id=5, depth=3] (leaf: prediction=0, purity=0.93, samples=114)
# ├── └── [Node id=9, depth=2, impurity=0.2716] (split: +1.00*x0 + -0.23 >= 0)
# ├── └── ├── [Node id=10, depth=3] (leaf: prediction=0, purity=1.00, samples=82)
# ├── └── └── [Node id=10, depth=3] (leaf: prediction=0, purity=0.77, samples=263)
# └── [Node id=15, depth=1, impurity=0.4298] (split: +1.00*x1 + -0.88 >= 0)
# └── ├── [Node id=16, depth=2, impurity=0.4466] (split: +1.00*x0 + -0.11 >= 0)
# └── ├── ├── [Node id=17, depth=3] (leaf: prediction=0, purity=0.99, samples=765)
# └── ├── └── [Node id=23, depth=3] (leaf: prediction=1, purity=0.51, samples=6019)
# └── └── [Node id=43, depth=2, impurity=0.0340] (split: +1.00*x1 + -0.90 >= 0)
# └── └── ├── [Node id=44, depth=3] (leaf: prediction=0, purity=0.82, samples=130)
# └── └── └── [Node id=46, depth=3] (leaf: prediction=0, purity=1.00, samples=1022)

# %%
hh.plot_tree_structure(depth=6, save=True)
# Out:
# [💾] Graphviz tree saved to: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\D_visual_comparisons_sd_vs_oblique\data\radial_segment_2d_label_noise_000_max_depth_8_min_purity_1_0/tree_structure_d6.pdf

# %%
hh.plot_metrics_vs_structure(save=True)
# Out:
# [💾] Figure saved to: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\D_visual_comparisons_sd_vs_oblique\data\radial_segment_2d_label_noise_000_max_depth_8_min_purity_1_0\metrics_vs_depth.pdf
# (<Figure size 600x450 with 1 Axes>,
#  <Axes: title={'center': 'Performance Metrics vs. Tree Depth'}, xlabel='Tree Depth', ylabel='Score'>)

# %%
hh.plot_metrics_vs_structure(save=True, x_axis="class1_leaf_count")
# Out:
# [💾] Figure saved to: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\D_visual_comparisons_sd_vs_oblique\data\radial_segment_2d_label_noise_000_max_depth_8_min_purity_1_0\metrics_vs_class1_leaf_count.pdf
# (<Figure size 600x450 with 1 Axes>,
#  <Axes: title={'center': 'Performance Metrics vs. Class 1 Leaf Count'}, xlabel='Class 1 Leaf Count', ylabel='Score'>)

# %%
hh.plot_tradeoff_path(save=True)
# Out:
# [💾] Figure saved to: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\D_visual_comparisons_sd_vs_oblique\data\radial_segment_2d_label_noise_000_max_depth_8_min_purity_1_0\coverage_density_path_depth.pdf

# %%
hh.plot_tradeoff_path(save=True, color_by="class1_leaf_count")
# Out:
# [💾] Figure saved to: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\D_visual_comparisons_sd_vs_oblique\data\radial_segment_2d_label_noise_000_max_depth_8_min_purity_1_0\coverage_density_path_class1_leaf_count.pdf

# %%
hh.plot_node_size_distribution(save=True)
# Out:
# [💾] Figure saved to: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\D_visual_comparisons_sd_vs_oblique\data\radial_segment_2d_label_noise_000_max_depth_8_min_purity_1_0\node_size_distribution.pdf
# (<Figure size 550x400 with 1 Axes>,
#  <Axes: title={'center': 'Node Size Distribution by Depth'}, xlabel='Tree Depth', ylabel='Samples per Node'>)

# %%
hh.plot_splits_2d_grid(save=True)
# Out:
# [💾] Figure saved to: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\D_visual_comparisons_sd_vs_oblique\data\radial_segment_2d_label_noise_000_max_depth_8_min_purity_1_0\clipped_oblique_splits.pdf

# %%
hh.plot_splits_2d_overlay(save=True)
# Out:
# [💾] Figure saved to: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\D_visual_comparisons_sd_vs_oblique\data\radial_segment_2d_label_noise_000_max_depth_8_min_purity_1_0\splits_2d_overlay.pdf

# %%
hh.plot_regions_2d_grid(save=True)
# Out:
# [💾] Figure saved to: C:\Users\jaspe\OneDrive\Desktop\Oblique-Decision-Tree-Algorithms-for-Scenario-Discovery\D_visual_comparisons_sd_vs_oblique\data\radial_segment_2d_label_noise_000_max_depth_8_min_purity_1_0\oblique_regions_by_depth.pdf
